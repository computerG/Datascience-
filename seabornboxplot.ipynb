# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
plt.rcParams.update({'figure.max_open_warning': 0})

# %%
crash = sns.load_dataset('car_crashes')

# %%
crash.head()
crash.min()
# Out:
# total                5.9
# speeding           1.792
# alcohol            1.593
# not_distracted      1.76
# no_previous          5.9
# ins_premium       641.96
# ins_losses         82.75
# abbrev                AK
# dtype: object

# %%
plt.figure(figsize = (9, 9))

plt.subplot(3,2,1)
sns.boxplot(y=crash['total'])

plt.subplot(3,2,2)
sns.boxplot(y=crash['alcohol'])

plt.subplot(3,2,3)
sns.boxplot(y=crash['speeding'])



plt.subplot(3,2,4)
sns.boxplot(y=crash['not_distracted'])

plt.subplot(3,2,5)
sns.boxplot(y=crash['no_previous'])

plt.subplot(3,2,6)
sns.boxplot(y=crash['ins_premium'])

plt.subplot(3,2,7)
sns.boxplot(y=crash['ins_losses'])
# Out:
# <img src="data:image/png;base64,..." width="1048.8">
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 23
#      20 plt.subplot(3,2,6)
#      21 sns.boxplot(y=crash['ins_premium'])
# ---> 23 plt.subplot(3,2,7)
#      24 sns.boxplot(y=crash['ins_losses'])
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:1323, in subplot(*args, **kwargs)
#    1320 fig = gcf()
#    1322 # First, search for an existing subplot with a matching spec.
# -> 1323 key = SubplotSpec._from_subplot_args(fig, args)
#    1325 for ax in fig.axes:
#    1326     # if we found an Axes at the position sort out if we can re-use it
#    1327     if ax.get_subplotspec() == key:
#    1328         # if the user passed no kwargs, re-use
#
# File ~\anaconda3\Lib\site-packages\matplotlib\gridspec.py:598, in SubplotSpec._from_subplot_args(figure, args)
#     596 else:
# ...

# %%
sns.boxplot(y = crash['not_distracted'])

#crash.boxplot( 'alcohol')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <Axes: ylabel='not_distracted'>
